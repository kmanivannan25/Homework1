# %%
from matplotlib import pyplot as plt

import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

plt.style.use('fivethirtyeight')
import pandas as pd
import numpy as np
from sklearn.datasets import load_boston

boston = pd.read_csv('C:\\Mani\\Data_Science\\Jupyter\\data-visualization-in-python\\datasets\\boston_housing_data.csv')

boston.head(5)
boston.describe()
boston.columns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

predictors = ['CRIM','ZN', 'INDUS', 'CHAS', 'LSTAT']

train, test = train_test_split(boston, train_size=0.5, random_state=1)


qualityTrain = pd.DataFrame(train, columns=boston.columns)
qualityTest = pd.DataFrame(test, columns=boston.columns)

lr = LinearRegression()
lr.fit(qualityTrain, qualityTest)
lr.score(qualityTrain, qualityTest)


yhat = lr.predict(qualityTest)
sns.jointplot(qualityTest, yhat);

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

predictors = ['RM','DIS', 'RAD']

train1, test1 = train_test_split(boston, train_size=0.7, random_state=1)


qualityTrain1 = pd.DataFrame(train, columns=boston.columns)
qualityTest1 = pd.DataFrame(test, columns=boston.columns)

lr = LinearRegression()
lr.fit(qualityTrain1, qualityTest1)
lr.score(qualityTrain1, qualityTest1)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

predictors = ['CRIM','ZN', 'INDUS', 'CHAS', 'LSTAT']

train, test = train_test_split(boston, train_size=0.7, random_state=1)


qualityTrain = pd.DataFrame(train, columns=boston.columns)
qualityTest = pd.DataFrame(test, columns=boston.columns)

lr = LinearRegression()
lr.fit(qualityTrain, qualityTest)
lr.score(qualityTrain, qualityTest)

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

predictors = ['CRIM','ZN', 'INDUS', 'CHAS', 'LSTAT']

train, test = train_test_split(boston, train_size=0.9, random_state=1)


qualityTrain = pd.DataFrame(train, columns=boston.columns)
qualityTest = pd.DataFrame(test, columns=boston.columns)

lr = LinearRegression()
lr.fit(qualityTrain, qualityTest)
lr.score(qualityTrain, qualityTest)

for i in range(5):
    print(results[i])
    
    
    import patsy

X = pd.DataFrame(boston.data, columns=boston.feature_names)
y = boston.target

df = X.copy()

# Add response to core DataFrame
df['MEDV'] = y
